# %% [markdown]
# # ***Model 2***

# %% [markdown]
# # **Data Prepare**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
from google.colab import files
files.upload()

# %%
# !ls -lha kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d andrewmvd/liver-tumor-segmentation

# !kaggle datasets download -d andrewmvd/liver-tumor-segmentation-part-2
# Out:
# Downloading liver-tumor-segmentation.zip to /content
# 100% 4.83G/4.84G [00:47<00:00, 164MB/s]
# 100% 4.84G/4.84G [00:47<00:00, 109MB/s]
# Downloading liver-tumor-segmentation-part-2.zip to /content
# 100% 10.8G/10.8G [01:30<00:00, 139MB/s]
# 100% 10.8G/10.8G [01:30<00:00, 128MB/s]

# %%
# !unzip liver-tumor-segmentation -d liver-tumor-segmentation
# Out:
# Archive:  liver-tumor-segmentation.zip
#   inflating: liver-tumor-segmentation/segmentations/segmentation-0.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-1.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-10.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-100.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-101.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-102.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-103.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-104.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-105.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-106.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-107.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-108.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-109.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-11.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-110.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-111.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-112.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-113.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-114.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-115.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-116.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-117.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-118.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-119.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-12.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-120.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-121.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-122.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-123.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-124.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-125.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-126.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-127.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-128.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-129.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-13.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-130.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-14.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-15.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-16.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-17.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-18.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-19.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-2.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-20.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-21.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-22.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-23.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-24.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-25.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-26.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-27.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-28.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-29.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-3.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-30.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-31.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-32.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-33.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-34.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-35.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-36.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-37.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-38.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-39.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-4.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-40.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-41.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-42.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-43.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-44.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-45.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-46.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-47.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-48.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-49.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-5.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-50.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-51.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-52.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-53.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-54.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-55.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-56.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-57.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-58.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-59.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-6.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-60.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-61.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-62.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-63.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-64.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-65.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-66.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-67.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-68.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-69.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-7.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-70.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-71.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-72.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-73.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-74.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-75.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-76.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-77.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-78.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-79.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-8.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-80.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-81.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-82.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-83.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-84.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-85.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-86.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-87.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-88.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-89.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-9.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-90.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-91.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-92.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-93.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-94.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-95.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-96.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-97.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-98.nii
#   inflating: liver-tumor-segmentation/segmentations/segmentation-99.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-0.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-1.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-10.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-2.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-3.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-4.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-5.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-6.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-7.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-8.nii
#   inflating: liver-tumor-segmentation/volume_pt1/volume-9.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-11.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-12.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-13.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-14.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-15.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-16.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-17.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-18.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-19.nii
#   inflating: liver-tumor-segmentation/volume_pt2/volume-20.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-21.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-22.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-23.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-24.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-25.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-26.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-27.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-28.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-29.nii
#   inflating: liver-tumor-segmentation/volume_pt3/volume-30.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-31.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-32.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-33.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-34.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-35.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-36.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-37.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-38.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-39.nii
#   inflating: liver-tumor-segmentation/volume_pt4/volume-40.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-41.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-42.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-43.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-44.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-45.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-46.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-47.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-48.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-49.nii
#   inflating: liver-tumor-segmentation/volume_pt5/volume-50.nii

# %%
# !rm -rf /content/liver-tumor-segmentation.zip

# %%
# !unzip liver-tumor-segmentation-part-2 -d liver-tumor-segmentation-part-2
# Out:
# Archive:  liver-tumor-segmentation-part-2.zip
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-100.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-51.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-52.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-53.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-54.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-55.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-56.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-57.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-58.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-59.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-60.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-61.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-62.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-63.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-64.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-65.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-66.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-67.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-68.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-69.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-70.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-71.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-72.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-73.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-74.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-75.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-76.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-77.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-78.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-79.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-80.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-81.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-82.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-83.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-84.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-85.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-86.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-87.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-88.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-89.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-90.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-91.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-92.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-93.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-94.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-95.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-96.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-97.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-98.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt6/volume-99.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-101.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-102.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-103.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-104.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-105.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-106.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-107.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-108.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-109.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-110.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-111.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-112.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-113.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-114.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-115.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-116.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-117.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-118.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-119.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-120.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-121.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-122.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-123.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-124.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-125.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-126.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-127.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-128.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-129.nii
#   inflating: liver-tumor-segmentation-part-2/volume_pt8/volume-130.nii

# %%
# !rm -rf /content/liver-tumor-segmentation-part-2.zip

# %% [markdown]
# # Remove extra files

# %%
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-0.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-1.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-10.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-2.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-3.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-4.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-5.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-6.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-7.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-8.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt1/volume-9.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-11.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-11.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-12.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-13.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-14.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-15.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-16.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-17.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-18.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-19.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt2/volume-20.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-21.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-22.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-23.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-24.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-25.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-26.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-27.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-28.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-29.nii
#!rm -rf /content/liver-tumor-segmentation/volume_pt3/volume-30.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-31.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-32.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-33.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-34.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-35.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-36.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-37.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-38.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-39.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt4/volume-40.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-41.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-42.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-43.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-44.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-45.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-46.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-47.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-48.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-49.nii
# !rm -rf /content/liver-tumor-segmentation/volume_pt5/volume-50.nii

# %% [markdown]
# # **Preprocessing**

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import glob

import nibabel as nib
import cv2
import imageio
from tqdm.notebook import tqdm
from ipywidgets import *
from PIL import Image

# %%
#!pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html > /dev/null
#!pip install --upgrade kornia > /dev/null
#!pip install allennlp==1.1.0.rc4 > /dev/null
#!pip install --upgrade fastai > /dev/null
import fastai; fastai.__version__

# %%
from fastai.basics import *
from fastai.vision.all import *
from fastai.data.transforms import *

# %%
# Create a meta file for nii files processing

file_list = []
for dirname, _, filenames in os.walk('/content/liver-tumor-segmentation'):
    for filename in filenames:
#         print(os.path.join(dirname, filename))
        file_list.append((dirname,filename))

for dirname, _, filenames in os.walk('/content/liver-tumor-segmentation-part-2'):
    for filename in filenames:
        file_list.append((dirname,filename))

df_files = pd.DataFrame(file_list, columns =['dirname', 'filename'])
df_files.sort_values(by=['filename'], ascending=True)
# Out:
#                                                  dirname              filename
# 53       /content/liver-tumor-segmentation/segmentations    segmentation-0.nii
# 82       /content/liver-tumor-segmentation/segmentations    segmentation-1.nii
# 2        /content/liver-tumor-segmentation/segmentations   segmentation-10.nii
# 108      /content/liver-tumor-segmentation/segmentations  segmentation-100.nii
# 105      /content/liver-tumor-segmentation/segmentations  segmentation-101.nii
# ..                                                   ...                   ...
# 175  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-95.nii
# 174  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-96.nii
# 201  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-97.nii
# 185  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-98.nii
# 188  /content/liver-tumor-segmentation-part-2/volume_pt6         volume-99.nii
#
# [221 rows x 2 columns]

# %%
# Map CT scan and label

df_files["mask_dirname"] = "" ; df_files["mask_filename"] = ""

for i in range(131):
    ct = f"volume-{i}.nii"
    mask = f"segmentation-{i}.nii"

    df_files.loc[df_files['filename'] == ct, 'mask_filename'] = mask
    df_files.loc[df_files['filename'] == ct, 'mask_dirname'] = "/content/liver-tumor-segmentation/segmentations"

# drop segment rows
df_files = df_files[df_files.mask_filename != ''].sort_values(by=['filename']).reset_index(drop=True)
print(len(df_files))
df_files
# Out:
# 90
#                                                 dirname        filename  \
# 0   /content/liver-tumor-segmentation-part-2/volume_pt6  volume-100.nii
# 1   /content/liver-tumor-segmentation-part-2/volume_pt8  volume-101.nii
# 2   /content/liver-tumor-segmentation-part-2/volume_pt8  volume-102.nii
# 3   /content/liver-tumor-segmentation-part-2/volume_pt8  volume-103.nii
# 4   /content/liver-tumor-segmentation-part-2/volume_pt8  volume-104.nii
# ..                                                  ...             ...
# 85  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-95.nii
# 86  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-96.nii
# 87  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-97.nii
# 88  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-98.nii
# 89  /content/liver-tumor-segmentation-part-2/volume_pt6   volume-99.nii
#
#                                        mask_dirname         mask_filename
# 0   /content/liver-tumor-segmentation/segmentations  segmentation-100.nii
# 1   /content/liver-tumor-segmentation/segmentations  segmentation-101.nii
# 2   /content/liver-tumor-segmentation/segmentations  segmentation-102.nii
# 3   /content/liver-tumor-segmentation/segmentations  segmentation-103.nii
# 4   /content/liver-tumor-segmentation/segmentations  segmentation-104.nii
# ..                                              ...                   ...
# 85  /content/liver-tumor-segmentation/segmentations   segmentation-95.nii
# 86  /content/liver-tumor-segmentation/segmentations   segmentation-96.nii
# 87  /content/liver-tumor-segmentation/segmentations   segmentation-97.nii
# 88  /content/liver-tumor-segmentation/segmentations   segmentation-98.nii
# 89  /content/liver-tumor-segmentation/segmentations   segmentation-99.nii
#
# [90 rows x 4 columns]

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample = 20
sample_ct   = read_nii(df_files.loc[sample,'dirname']+"/"+df_files.loc[sample,'filename'])
sample_mask  = read_nii(df_files.loc[sample,'mask_dirname']+"/"+df_files.loc[sample,'mask_filename'])
sample_ct.shape, sample_mask.shape
# Out:
# ((512, 512, 424), (512, 512, 424))

# %%
print(np.amin(sample_ct), np.amax(sample_ct))
print(np.amin(sample_mask), np.amax(sample_mask))
# Out:
# -1024.0 3071.0
# 0.0 2.0

# %%
# Preprocess the nii file
# Source https://docs.fast.ai/medical.imaging

dicom_windows = types.SimpleNamespace(
    brain=(80,40),
    subdural=(254,100),
    stroke=(8,32),
    brain_bone=(2800,600),
    brain_soft=(375,40),
    lungs=(1500,-600),
    mediastinum=(350,50),
    abdomen_soft=(400,50),
    liver=(150,30),
    spine_soft=(250,50),
    spine_bone=(1800,400),
    custom = (200,60)
)

@patch
def windowed(self:Tensor, w, l):
    px = self.clone()
    px_min = l - w//2
    px_max = l + w//2
    px[px<px_min] = px_min
    px[px>px_max] = px_max
    return (px-px_min) / (px_max-px_min)

plt.imshow(tensor(sample_ct[...,50].astype(np.float32)).windowed(*dicom_windows.liver), cmap=plt.cm.bone);

# %%
def plot_sample(array_list, color_map = 'nipy_spectral'):
    '''
    Plots and a slice with all available annotations
    '''
    fig = plt.figure(figsize=(18,15))

    plt.subplot(1,4,1)
    plt.imshow(array_list[0], cmap='bone')
    plt.title('Original Image')

    plt.subplot(1,4,2)
    plt.imshow(tensor(array_list[0].astype(np.float32)).windowed(*dicom_windows.liver), cmap='bone');
    plt.title('Windowed Image')

    plt.subplot(1,4,3)
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Mask')

    plt.subplot(1,4,4)
    plt.imshow(array_list[0], cmap='bone')
    plt.imshow(array_list[1], alpha=0.5, cmap=color_map)
    plt.title('Liver & Mask')

    plt.show()

# %%
sample=50
sample_slice = tensor(sample_ct[...,sample].astype(np.float32))

plot_sample([sample_ct[...,sample], sample_mask[...,sample]])

# %%
# Check the mask values
mask = Image.fromarray(sample_mask[...,sample].astype('uint8'), mode="L")
unique, counts = np.unique(mask, return_counts=True)
print( np.array((unique, counts)).T)
# Out:
# [[     0 262144]]

# %%
# Preprocessing functions
# Source https://docs.fast.ai/medical.imaging

class TensorCTScan(TensorImageBW): _show_args = {'cmap':'bone'}

@patch
def freqhist_bins(self:Tensor, n_bins=100):
    "A function to split the range of pixel values into groups, such that each group has around the same number of pixels"
    imsd = self.view(-1).sort()[0]
    t = torch.cat([tensor([0.001]),
                   torch.arange(n_bins).float()/n_bins+(1/2/n_bins),
                   tensor([0.999])])
    t = (len(imsd)*t).long()
    return imsd[t].unique()

@patch
def hist_scaled(self:Tensor, brks=None):
    "Scales a tensor using `freqhist_bins` to values between 0 and 1"
    if self.device.type=='cuda': return self.hist_scaled_pt(brks)
    if brks is None: brks = self.freqhist_bins()
    ys = np.linspace(0., 1., len(brks))
    x = self.numpy().flatten()
    x = np.interp(x, brks.numpy(), ys)
    return tensor(x).reshape(self.shape).clamp(0.,1.)


@patch
def to_nchan(x:Tensor, wins, bins=None):
    res = [x.windowed(*win) for win in wins]
    if not isinstance(bins,int) or bins!=0: res.append(x.hist_scaled(bins).clamp(0,1))
    dim = [0,1][x.dim()==3]
    return TensorCTScan(torch.stack(res, dim=dim))


@patch
def save_jpg(x:(Tensor), path, wins, bins=None, quality=90):
    fn = Path(path).with_suffix('.jpg')
    x = (x.to_nchan(wins, bins)*255).byte()
    im = Image.fromarray(x.permute(1,2,0).numpy(), mode=['RGB','CMYK'][x.shape[0]==4])
    im.save(fn, quality=quality)

_,axs=subplots(1,1)

sample_slice.save_jpg('test.jpg', [dicom_windows.liver,dicom_windows.custom])
show_image(Image.open('test.jpg'), ax=axs[0])
# Out:
# <AxesSubplot:>

# %%
# Make custom JPG files for Unet training
# Total number of 131 nii files contains 67072 slices

GENERATE_JPG_FILES = True   # warning: generation takes ~ 1h

if (GENERATE_JPG_FILES) :

    path = Path(".")

    os.makedirs('train_images',exist_ok=True)
    os.makedirs('train_masks',exist_ok=True)

    for ii in tqdm(range(0,len(df_files),3)): # take 1/3 nii files for training
        curr_ct        = read_nii(df_files.loc[ii,'dirname']+"/"+df_files.loc[ii,'filename'])
        curr_mask      = read_nii(df_files.loc[ii,'mask_dirname']+"/"+df_files.loc[ii,'mask_filename'])
        curr_file_name = str(df_files.loc[ii,'filename']).split('.')[0]
        curr_dim       = curr_ct.shape[2] # 512, 512, curr_dim

        for curr_slice in range(0,curr_dim,2): # export every 2nd slice for training
            data = tensor(curr_ct[...,curr_slice].astype(np.float32))
            mask = Image.fromarray(curr_mask[...,curr_slice].astype('uint8'), mode="L")
            data.save_jpg(f"train_images/{curr_file_name}_slice_{curr_slice}.jpg", [dicom_windows.liver,dicom_windows.custom])
            mask.save(f"train_masks/{curr_file_name}_slice_{curr_slice}_mask.png")
else:

    path = Path("/content/liver-segmentation-with-fastai-v2") # read jpg from saved kernel output
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# # **Training**

# %%
bs = 16
im_size = 128

codes = np.array(["background","liver","tumor"])

def get_x(fname:Path): return fname
def label_func(x): return path/'train_masks'/f'{x.stem}_mask.png'

tfms = [IntToFloatTensor(),Normalize()]

db = DataBlock(blocks=(ImageBlock(),MaskBlock(codes)),  #codes = {"Backround": 0,"Liver": 1,"Tumor": 2}
               batch_tfms=tfms,
               splitter=RandomSplitter(),
               item_tfms=[Resize(im_size)],
               get_items=get_image_files,
               get_y=label_func
              )

ds = db.datasets(source=path/'train_images')

# %%
idx=215
imgs = [ds[idx][0],ds[idx][1]]
fig,axs = plt.subplots(1, 2)
for i,ax in enumerate(axs.flatten()):
    ax.axis('off')
    ax.imshow(imgs[i]) #, cmap='gray'

# %%
unique, counts = np.unique(array(ds[idx][1]), return_counts=True)

print( np.array((unique, counts)).T)
# Out:
# [[     0 218457]
#  [     1  43687]]

# %%
dls = db.dataloaders(path/'train_images',bs = bs) #, num_workers=0
dls.show_batch()

# %%
def foreground_acc(inp, targ, bkg_idx=0, axis=1):  # exclude a background from metric
    "Computes non-background accuracy for multiclass segmentation"
    targ = targ.squeeze(1)
    mask = targ != bkg_idx
    return (inp.argmax(dim=axis)[mask]==targ[mask]).float().mean()

def cust_foreground_acc(inp, targ):  # # include a background into the metric
    return foreground_acc(inp=inp, targ=targ, bkg_idx=3, axis=1) # 3 is a dummy value to include the background which is 0

# %%
learn = unet_learner(dls, resnet34, loss_func=CrossEntropyLossFlat(axis=1), metrics=[foreground_acc, cust_foreground_acc])
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
'''learn = unet_learner(dls,
                     resnet50,
                     loss_func=CrossEntropyLossFlat(axis=1),
                     metrics=[foreground_acc, cust_foreground_acc]) '''

'''learn = cnn_learner(dls,
                     resnet50,
                     loss_func=CrossEntropyLossFlat(axis=1),
                     metrics=[foreground_acc, cust_foreground_acc]) '''

'''learn = cnn_learner(dls,
                     resnet34,
                     loss_func=CrossEntropyLossFlat(axis=1),
                     metrics=[foreground_acc, cust_foreground_acc]) '''
# Out:
# 'learn = unet_learner(dls,\n                     resnet50,\n                     loss_func=CrossEntropyLossFlat(axis=1),\n                     metrics=[foreground_acc, cust_foreground_acc]) '

# %%
learn.fine_tune(1, wd=0.1, cbs=SaveModelCallback() )
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>cust_foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.022155</td>
#       <td>0.030667</td>
#       <td>0.470277</td>
#       <td>0.989871</td>
#       <td>2:29:30</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.03066686913371086.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>foreground_acc</th>
#       <th>cust_foreground_acc</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.005859</td>
#       <td>0.004756</td>
#       <td>0.943049</td>
#       <td>0.998264</td>
#       <td>3:16:44</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.004756166599690914.

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# Save the model
learn.export(path/f'Liver_segmentation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7ce2832544d2> in <module>
#       1 # Save the model
# ----> 2 learn.export(path/f'Liver_segmentation')
#
# NameError: name 'learn' is not defined

# %% [markdown]
# # **Testing**

# %%
# Load saved model
if (GENERATE_JPG_FILES) :

    tfms = [Resize(im_size), IntToFloatTensor(),Normalize()]
    learn0               = load_learner(path/f'Liver_segmentation',cpu=False )
    learn0.dls.transform = tfms

# %%
def nii_tfm(fn,wins):

    test_nii  = read_nii(fn)
    curr_dim  = test_nii.shape[2] # 512, 512, curr_dim
    slices = []

    for curr_slice in range(curr_dim):
        data = tensor(test_nii[...,curr_slice].astype(np.float32))
        data = (data.to_nchan(wins)*255).byte()
        slices.append(TensorImage(data))

    return slices

# %%
tst = 20

test_nii   = read_nii(df_files.loc[tst,'dirname']+"/"+df_files.loc[tst,'filename'])
test_mask  = read_nii(df_files.loc[tst,'mask_dirname']+"/"+df_files.loc[tst,'mask_filename'])
print(test_nii.shape)

test_slice_idx = 300

sample_slice = tensor(test_nii[...,test_slice_idx].astype(np.float32))

plot_sample([test_nii[...,test_slice_idx], test_mask[...,test_slice_idx]])

# %%
plt.imsave('f.png', test_mask[..., test_slice_idx])

# %%
# Prepare a nii test file for prediction

test_files = nii_tfm(df_files.loc[tst,'dirname']+"/"+df_files.loc[tst,'filename'],[dicom_windows.liver, dicom_windows.custom])
print("Number of test slices: ",len(test_files))

# %%
# Check an input for a test file
show_image(test_files[test_slice_idx])

# %%
test_dl = learn0.dls.test_dl(test_files)
preds, y = learn0.get_preds(dl=test_dl)

predicted_mask = np.argmax(preds, axis=1)
plt.imshow(predicted_mask[test_slice_idx])

# %%
a=np.array(predicted_mask[test_slice_idx])
np.amin(a),np.amax(a),

# %%
np.sum(predicted_mask == 255)

# %%
spot_img = cv2.imread('test_mask', 0)
binary_img = cv2.threshold(spot_img, 127, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
cv2.countNonZero(binary_img)

# %%
code_img = cv2.imread(r'test_mask', 0)
cv2.countNonZero(code_img)
